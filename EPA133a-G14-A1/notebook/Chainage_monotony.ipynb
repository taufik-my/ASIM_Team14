# %%
import pandas as pd
import numpy as np

# %%
#Function to check monotony in datasets

def check_chainage_monotony(df):
    # convert the chainage column to numeric values, if value cannot be converted it becomes NaN
    df["chainage"] = pd.to_numeric(df["chainage"], errors="coerce")
    # create empty list to store True or False values indicating whether there's monotony within each road group
    report = []
    # loop through each group of rows grouped by "road"
    for road, group in df.groupby("road"):
        # reset index inside each group so iteration start from 0 (and drop old index column)
        group = group.reset_index(drop=True)
        # variable to keep track of previous chainage value
        prev_chainage = None
        # iterate through each row in the grouped DataFrame
        for i, row in group.iterrows():
            current_chainage = row["chainage"]

            # it it's the first row in the group, it will automatically be marked as monotone (True)
            if prev_chainage is None:
                report.append(True)
            else:
                # Check if current chainage is greater than or equal to the previous one
                report.append(current_chainage >= prev_chainage)
            # update chainage for next iteration
            prev_chainage = current_chainage

    # add the report as new column to original dataframe
    df["monotone"] = report

    not_monotone = df.groupby("road")["monotone"].all().eq(False).sum()
    # print results
    if not_monotone == 0:
        print("All roads in the dataset have chainage monotony")
    else:
        print(not_monotone, "roads break chainage monotony")
        road_monotone = df.groupby("road")["monotone"].all()
        broken_roads = road_monotone[road_monotone ==False].index
        print("Roads that break monotony:", broken_roads)

# %%
df_roads = pd.read_csv("../data/raw/Roads_InfoAboutEachLRP.csv")

check_chainage_monotony(df_roads)
# Out:
# All roads in the dataset have chainage monotony

# %%
df_bridges = pd.read_excel("../data/raw/BMMS_overview.xlsx")

check_chainage_monotony(df_bridges)

# the output is only one road with broken montony R750, 
# but seems this doesn't have coordinates nor much data, likely to be road
# in conclusion, both datasets
# Out:
# 507 roads break chainage monotony
# Roads that break monotony: Index(['N1', 'N102', 'N104', 'N105', 'N106', 'N107', 'N108', 'N110', 'N2',
#        'N204',
#        ...
#        'Z8716', 'Z8717', 'Z8803', 'Z8804', 'Z8806', 'Z8810', 'Z8814', 'Z8910',
#        'Z8913', 'Z8915'],
#       dtype='object', name='road', length=507)

# %%
# Observing the dataset, the roads seem to be all over the place
# N1 in initial rows but also afterwards
# Here's a function to group and sort them in order

def fix_chainage_monotony(df): 
    df = df.copy()
    # group frist by road and sort each road by chainage
    df_sorted = df.sort_values(by=["road", "chainage"]).reset_index(drop=True)
    return df_sorted

df_sorted_bridges = fix_chainage_monotony(df_bridges)
check_chainage_monotony(df_sorted_bridges)
# Out:
# 1 roads break chainage monotony
# Roads that break monotony: Index(['R750'], dtype='object', name='road')

# %%
# Check of road R750
roadR750 = df_sorted_bridges[df_sorted_bridges["road"] == "R750"]
roadR750.tail(30)
# Out:
#       road      km               type  LRPName               name  length  \
# 7668  R750   5.765       Arch Masonry  LRP006a                  .    1.90
# 7669  R750   6.135  RCC Girder Bridge  LRP006b     Daitala Bridge   41.60
# 7670  R750   8.932       Slab Culvert  LRP009a                  .    3.80
# 7671  R750  10.016       Slab Culvert  LRP010a                  .    3.80
# 7672  R750  11.780       Slab Culvert  LRP012a                  .    4.20
# 7673  R750  12.825       Slab Culvert  LRP013a                  .    4.00
# 7674  R750  14.050       Arch Masonry  LRP014b                  .    3.10
# 7675  R750  14.623       Slab Culvert  LRP015a                  .    4.15
# 7676  R750  15.157       Slab Culvert  LRP016a                  .    4.10
# 7677  R750  16.028       Slab Culvert  LRP017a                  .    4.16
# 7678  R750  16.566       Slab Culvert  LRP018a                  .    4.05
# 7679  R750  17.362       Arch Masonry  LRP018b                  .    3.20
# 7680  R750  18.448        Box Culvert  LRP019a                  .    3.50
# 7681  R750  19.177        Box Culvert  LRP020a                  .    4.07
# 7682  R750  19.414        Box Culvert  LRP020b                  .   13.00
# 7683  R750  20.534        Box Culvert  LRP022a                  .    6.87
# 7684  R750  21.047        Box Culvert  LRP022b                  .    6.95
# 7685  R750  21.434         RCC Bridge  LRP022c                  .   30.95
# 7686  R750  22.673         RCC Bridge  LRP024a                  .    8.15
# 7687  R750  23.260        Box Culvert  LRP024b                  .    6.90
# 7688  R750  24.180   PC Girder Bridge  LRP025a                  .   91.35
# 7689  R750  24.180  RCC Girder Bridge  LRP025a  Tularampur Bridge   91.50
# 7690  R750  25.181       Slab Culvert  LRP026a                  .    7.40
# 7691  R750  26.069       Arch Masonry  LRP027a                  .    7.56
# 7692  R750  26.593        Box Culvert  LRP028a                  .    6.75
# 7693  R750  26.909  RCC Girder Bridge  LRP028b                  .   46.15
# 7694  R750  27.412       Arch Masonry  LRP028d                  .    5.65
# 7695  R750  28.271       Arch Masonry  LRP029a                  .   21.10
# 7696  R750  29.049       Arch Masonry  LRP030a                  .   21.10
# 7697  R750     NaN  RCC Girder Bridge  LRP006b     Daitala Bridge   41.50
#
#      condition  structureNr             roadName  chainage  ...  \
# 7668         C       103281  Jessore-Narail Road     5.765  ...
# 7669         C       104032  Jessore-Narail Road     6.135  ...
# 7670         B       104035  Jessore-Narail Road     8.932  ...
# 7671         C       104036  Jessore-Narail Road    10.016  ...
# 7672         C       104039  Jessore-Narail Road    11.780  ...
# 7673         C       104046  Jessore-Narail Road    12.825  ...
# 7674         B       104050  Jessore-Narail Road    14.050  ...
# 7675         A       104063  Jessore-Narail Road    14.623  ...
# 7676         B       104069  Jessore-Narail Road    15.157  ...
# 7677         C       104078  Jessore-Narail Road    16.028  ...
# 7678         A       104091  Jessore-Narail Road    16.566  ...
# 7679         C       104098  Jessore-Narail Road    17.362  ...
# 7680         A       104100  Jessore-Narail Road    18.448  ...
# 7681         A       104107  Jessore-Narail Road    19.177  ...
# 7682         C       104109  Jessore-Narail Road    19.414  ...
# 7683         A       104118  Jessore-Narail Road    20.534  ...
# 7684         A       104117  Jessore-Narail Road    21.047  ...
# 7685         C       104122  Jessore-Narail Road    21.434  ...
# 7686         C       104123  Jessore-Narail Road    22.673  ...
# 7687         A       104124  Jessore-Narail Road    23.260  ...
# 7688         C       104266  Jessore-Narail Road    24.180  ...
# 7689         C       119555  Jessore-Narail Road    24.180  ...
# 7690         D       104280  Jessore-Narail Road    25.181  ...
# 7691         D       104285  Jessore-Narail Road    26.069  ...
# 7692         C       104329  Jessore-Narail Road    26.593  ...
# 7693         C       105673  Jessore-Narail Road    26.909  ...
# 7694         B       104354  Jessore-Narail Road    27.412  ...
# 7695         C       104357  Jessore-Narail Road    28.271  ...
# 7696         C       104363  Jessore-Narail Road    29.049  ...
# 7697         A       118833  Jessore-Narail Road       NaN  ...
#
#       constructionYear  spans    zone   circle division sub-division  \
# 7668            1980.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7669            1976.0    3.0  Khulna  Jessore  Jessore    Jessore-2
# 7670            1980.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7671            1985.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7672            1985.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7673            1980.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7674            1976.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7675            1985.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7676            1985.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7677            1980.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7678            1985.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7679            1976.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7680            1990.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7681            1990.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7682            2003.0    2.0  Khulna  Jessore  Jessore    Jessore-2
# 7683            2003.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7684            1990.0    1.0  Khulna  Jessore  Jessore    Jessore-2
# 7685            1974.0    4.0  Khulna  Jessore  Jessore    Jessore-2
# 7686            1985.0    1.0  Khulna  Jessore   Narail       Narail
# 7687            1990.0    1.0  Khulna  Jessore   Narail       Narail
# 7688            1972.0    3.0  Khulna  Jessore   Narail       Narail
# 7689               NaN    NaN  Khulna  Jessore   Narail       Narail
# 7690            1969.0    2.0  Khulna  Jessore   Narail       Narail
# 7691            1976.0    2.0  Khulna  Jessore   Narail       Narail
# 7692            1990.0    1.0  Khulna  Jessore   Narail       Narail
# 7693            1968.0    5.0  Khulna  Jessore   Narail       Narail
# 7694            1985.0    1.0  Khulna  Jessore   Narail       Narail
# 7695            1980.0    2.0  Khulna  Jessore   Narail       Narail
# 7696            1980.0    2.0  Khulna  Jessore   Narail       Narail
# 7697               NaN    NaN  Khulna  Jessore  Jessore    Jessore-2
#
#             lat        lon  EstimatedLoc monotone
# 7668  23.166583  89.276500          bcs1     True
# 7669  23.168056  89.279722          bcs1     True
# 7670  23.184361  89.299778          bcs1     True
# 7671  23.184444  89.310278          bcs1     True
# 7672  23.185778  89.327472          bcs1     True
# 7673  23.187778  89.337500          bcs1     True
# 7674  23.187778  89.349167          bcs1     True
# 7675  23.186833  89.354722          bcs1     True
# 7676  23.185556  89.359722          bcs1     True
# 7677  23.187222  89.367500          bcs1     True
# 7678  23.188611  89.372500          bcs1     True
# 7679  23.188444  89.380250          bcs1     True
# 7680  23.183333  89.389167          bcs1     True
# 7681  23.180917  89.395861          bcs1     True
# 7682  23.180639  89.397944          bcs1     True
# 7683  23.178889  89.408889          bcs1     True
# 7684  23.177500  89.413611          bcs1     True
# 7685  23.176306  89.417250          bcs1     True
# 7686  23.172500  89.428333          bcs1     True
# 7687  23.170000  89.433611          bcs1     True
# 7688  23.166944  89.441667          bcs1     True
# 7689        NaN        NaN          bcs1     True
# 7690  23.163444  89.450778          bcs1     True
# 7691  23.163222  89.459000          bcs1     True
# 7692  23.163611  89.464444          bcs1     True
# 7693  23.163889  89.467500          bcs1     True
# 7694  23.164139  89.469556          bcs1     True
# 7695  23.164806  89.480667          bcs1     True
# 7696  23.165417  89.488222          bcs1     True
# 7697        NaN        NaN          bcs1    False
#
# [30 rows x 21 columns]

# %%
# Chainage breaks because one entry in the road has a NaN value in the chainage column 
# Since this row has the same LRP, name and length as another entry, we assume it refers to the same bridge
# We drop the row with NaN value in chainage

df_cleaned_bridges = df_sorted_bridges.drop(df_sorted_bridges[(df_sorted_bridges['chainage'].isna()) & (df_sorted_bridges["road"] == "R750")].index)
check_chainage_monotony(df_cleaned_bridges)
# Out:
# All roads in the dataset have chainage monotony

# %% [markdown]
# df_sorted_bridges.to_csv()
